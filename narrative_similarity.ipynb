# %% [markdown]
# Install

# %%
# !nvidia-smi
# !pip install -q transformers sentence-transformers datasets scikit-learn pyyaml accelerate
# Out:
# Thu Dec 11 22:52:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Cell 2: Clone repo

# %%
REPO_URL = "https://github.com/ppertuzduran/SEMEVAL2026-TASK4.git"  # ← CHANGE THIS
# !git clone {REPO_URL} /content/project
# %cd /content/project
# Out:
# Cloning into '/content/project'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 112 (delta 53), reused 86 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 102.23 KiB | 865.00 KiB/s, done.
# Resolving deltas: 100% (53/53), done.
# /content/project

# %% [markdown]
# Cell 3: Mount Drive + Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0, '/content/project/training')
from colab_utils import setup_colab_environment
paths = setup_colab_environment(project_name="narrative_similarity")
# Out:
# Mounted at /content/drive
# 🔧 Setting up Google Colab environment...
# ✓ Drive already mounted
# ✓ Drive directory: /content/drive/MyDrive/narrative_similarity
# ✓ Data files found in Drive
# ✓ Working directory: /content/project
# ✓ Scripts from repository: /content/project
# ✓ Setup complete!
#   - Scripts: /content/project
#   - Data: /content/drive/MyDrive/narrative_similarity/data
#   - Models: /content/drive/MyDrive/narrative_similarity/models

# %% [markdown]
# Prepare **Data**

# %%
# !python training/prepare_data.py
# Out:
# ============================================================
# DATA PREPARATION - GOOGLE COLAB
# ============================================================
# 🔧 Setting up Google Colab environment...
# ✓ Drive already mounted
# ✓ Drive directory: /content/drive/MyDrive/narrative_similarity
# ✓ Data files found in Drive
# ✓ Working directory: /content/project
# ✓ Scripts from repository: /content/project
# ✓ Setup complete!
#   - Scripts: /content/project
#   - Data: /content/drive/MyDrive/narrative_similarity/data
#   - Models: /content/drive/MyDrive/narrative_similarity/models
#
# 🎮 GPU: Tesla T4
# 💾 VRAM: 14.74 GB
# Loading Track A data...
# Loaded 200 samples
#
# Creating triplet dataset for Track B...
# Saved 200 triplets
#
# Creating pairwise dataset for Track B...
# Saved 400 pairs
#
# Creating cross-encoder dataset for Track A...
# Saved 400 cross-encoder samples
#
# Creating 5-fold splits...
# Saved 5 fold splits
#
# Creating train/val split (80/20) for Track B...
# Train: 160, Val: 40
#
# ✓ Data preparation complete!
# All prepared data saved to: /content/drive/MyDrive/narrative_similarity/data/prepared

# %% [markdown]
# Train Track B (~20 min)**bold text**

# %%
# !python training/train_track_b.py
# Out:
# 2025-12-11 21:02:07.313406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765486927.345327    1724 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765486927.355083    1724 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765486927.378502    1724 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765486927.378530    1724 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765486927.378539    1724 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765486927.378551    1724 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-11 21:02:07.385104: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ============================================================
# TRACK B TRAINING - GOOGLE COLAB
# ============================================================
# 🔧 Setting up Google Colab environment...
# ✓ Drive already mounted
# ✓ Drive directory: /content/drive/MyDrive/narrative_similarity
# ✓ Data files found in Drive
# ✓ Working directory: /content/project
# ✓ Scripts from repository: /content/project
# ✓ Setup complete!
#   - Scripts: /content/project
#   - Data: /content/drive/MyDrive/narrative_similarity/data
#   - Models: /content/drive/MyDrive/narrative_similarity/models
#
# 🎮 GPU: Tesla T4
# 💾 VRAM: 14.74 GB
# Using device: cuda
# GPU: Tesla T4
#
# Loading base model: BAAI/bge-base-en-v1.5
# modules.json: 100% 349/349 [00:00<00:00, 2.96MB/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 1.20MB/s]
# README.md: 94.6kB [00:00, 144MB/s]
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 540kB/s]
# config.json: 100% 777/777 [00:00<00:00, 7.83MB/s]
# model.safetensors: 100% 438M/438M [00:03<00:00, 129MB/s]
# tokenizer_config.json: 100% 366/366 [00:00<00:00, 3.30MB/s]
# vocab.txt: 232kB [00:00, 102MB/s]
# tokenizer.json: 711kB [00:00, 179MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 1.20MB/s]
# config.json: 100% 190/190 [00:00<00:00, 1.03MB/s]
#
# Loading triplets...
# Loaded 200 triplets
# Loading pairs...
# Loaded 400 pairs
# Loading cross-encoder data for pairwise softmax...
# Loaded 400 triple samples
#
# Train triplets: 160
# Val triplets: 40
# Train pairs: 320
# Train cross-encoder (for pairwise softmax): 320
#
# ============================================================
# Phase 1: Training with PairwiseSoftmaxLoss (direct metric optimization)...
# ============================================================
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.23.1
# wandb: W&B syncing is set to `offline` in this directory. Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# wandb: Run data is saved locally in /content/project/wandb/offline-run-20251211_210233-jgn9pli5
#  20% 14/70 [00:12<00:39,  1.41it/s]
# Epoch 1.0, Step 14: Accuracy = 0.6450
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
#  40% 28/70 [00:45<00:33,  1.26it/s]
# Epoch 2.0, Step 28: Accuracy = 0.6900
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
#  60% 42/70 [01:07<00:22,  1.26it/s]
# Epoch 3.0, Step 42: Accuracy = 0.7700
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
#  80% 56/70 [01:28<00:11,  1.26it/s]
# Epoch 4.0, Step 56: Accuracy = 0.8100
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
# 100% 70/70 [01:49<00:00,  1.22it/s]
# Epoch 5.0, Step 70: Accuracy = 0.8550
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
# {'train_runtime': 128.0549, 'train_samples_per_second': 12.495, 'train_steps_per_second': 0.547, 'train_loss': 0.6717515672956195, 'epoch': 5.0}
# 100% 70/70 [02:02<00:00,  1.75s/it]
#
# Epoch 0, Step 0: Accuracy = 0.8550
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
#
# ============================================================
# Phase 2: Fine-tuning with TripletLoss...
# ============================================================
#  20% 7/35 [00:06<00:24,  1.12it/s]
# Epoch 1.0, Step 7: Accuracy = 0.8550
#  40% 14/35 [00:15<00:21,  1.00s/it]
# Epoch 2.0, Step 14: Accuracy = 0.8750
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
#  60% 21/35 [00:31<00:16,  1.19s/it]
# Epoch 3.0, Step 21: Accuracy = 0.8750
#  80% 28/35 [00:47<00:08,  1.21s/it]
# Epoch 4.0, Step 28: Accuracy = 0.8750
# 100% 35/35 [00:55<00:00,  1.10it/s]
# Epoch 5.0, Step 35: Accuracy = 0.8750
# {'train_runtime': 56.5612, 'train_samples_per_second': 14.144, 'train_steps_per_second': 0.619, 'train_loss': 0.3717635835920061, 'epoch': 5.0}
# 100% 35/35 [00:56<00:00,  1.62s/it]
#
# ============================================================
# Fine-tuning with MultipleNegativesRankingLoss...
# ============================================================
#
# Epoch 0, Step 0: Accuracy = 0.8750
# New best accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
#  20% 7/35 [00:04<00:16,  1.66it/s]
# Epoch 1.0, Step 7: Accuracy = 0.8750
#  40% 14/35 [00:10<00:14,  1.42it/s]
# Epoch 2.0, Step 14: Accuracy = 0.8650
#  60% 21/35 [00:22<00:12,  1.17it/s]
# Epoch 3.0, Step 21: Accuracy = 0.8600
#  80% 28/35 [00:28<00:04,  1.53it/s]
# Epoch 4.0, Step 28: Accuracy = 0.8500
# 100% 35/35 [00:34<00:00,  1.51it/s]
# Epoch 5.0, Step 35: Accuracy = 0.8300
# {'train_runtime': 36.1, 'train_samples_per_second': 22.161, 'train_steps_per_second': 0.97, 'train_loss': 2.027044023786272, 'epoch': 5.0}
# 100% 35/35 [00:36<00:00,  1.03s/it]
#
# ============================================================
# Training complete!
# ============================================================
#
# Final best model accuracy: 0.8750
# Model saved to: /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/project/wandb/offline-run-20251211_210233-jgn9pli5
# wandb: Find logs at: wandb/offline-run-20251211_210233-jgn9pli5/logs

# %% [markdown]
# Train Track A (~50 min)

# %%
# !python training/train_track_a.py
# Out:
# ============================================================
# TRACK A TRAINING - GOOGLE COLAB
# ============================================================
# 🔧 Setting up Google Colab environment...
# ✓ Drive already mounted
# ✓ Drive directory: /content/drive/MyDrive/narrative_similarity
# ✓ Data files found in Drive
# ✓ Working directory: /content/project
# ✓ Scripts from repository: /content/project
# ✓ Setup complete!
#   - Scripts: /content/project
#   - Data: /content/drive/MyDrive/narrative_similarity/data
#   - Models: /content/drive/MyDrive/narrative_similarity/models
#
# 🎮 GPU: Tesla T4
# 💾 VRAM: 14.74 GB
# Training with 5-fold cross-validation
#
# ============================================================
# Fold 1/5
# ============================================================
#
# Loading model: roberta-large
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 122kB/s]
# config.json: 100% 482/482 [00:00<00:00, 3.52MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 1.42MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.15MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 42.0MB/s]
# 2025-12-11 21:07:26.768515: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765487246.785785    3141 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765487246.790650    3141 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765487246.805427    3141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765487246.805457    3141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765487246.805461    3141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765487246.805464    3141 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-11 21:07:26.809951: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 1.42G/1.42G [00:10<00:00, 134MB/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# Starting training for fold 0...
# Train samples: 160, Val samples: 40
#
# Epoch 1/5
# /content/project/training/train_track_a.py:128: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp else None
# Training:   0% 0/27 [00:00<?, ?it/s]/content/project/training/train_track_a.py:143: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Training: 100% 27/27 [00:27<00:00,  1.00s/it, loss=0.647, acc=0.569]
# Evaluating: 100% 7/7 [00:07<00:00,  1.09s/it]
# Train Loss: 0.6943, Train Acc: 0.5687
# Val Loss: 0.6879, Val Acc: 0.6000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
#
# Epoch 2/5
# Training: 100% 27/27 [00:28<00:00,  1.05s/it, loss=0.724, acc=0.619]
# Evaluating: 100% 7/7 [00:07<00:00,  1.11s/it]
# Train Loss: 0.6705, Train Acc: 0.6188
# Val Loss: 0.6603, Val Acc: 0.6500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
#
# Epoch 3/5
# Training: 100% 27/27 [00:26<00:00,  1.00it/s, loss=0.658, acc=0.6]
# Evaluating: 100% 7/7 [00:07<00:00,  1.14s/it]
# Train Loss: 0.6494, Train Acc: 0.6000
# Val Loss: 0.6099, Val Acc: 0.6750
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
#
# Epoch 4/5
# Training: 100% 27/27 [00:27<00:00,  1.03s/it, loss=0.42, acc=0.794]
# Evaluating: 100% 7/7 [00:07<00:00,  1.14s/it]
# Train Loss: 0.5423, Train Acc: 0.7937
# Val Loss: 0.5073, Val Acc: 0.8000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
#
# Epoch 5/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.609, acc=0.875]
# Evaluating: 100% 7/7 [00:08<00:00,  1.16s/it]
# Train Loss: 0.4105, Train Acc: 0.8750
# Val Loss: 0.4561, Val Acc: 0.8250
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
#
# ============================================================
# Fold 2/5
# ============================================================
#
# Loading model: roberta-large
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# Starting training for fold 1...
# Train samples: 160, Val samples: 40
#
# Epoch 1/5
# Training: 100% 27/27 [00:28<00:00,  1.04s/it, loss=0.65, acc=0.481]
# Evaluating: 100% 7/7 [00:07<00:00,  1.14s/it]
# Train Loss: 0.6990, Train Acc: 0.4813
# Val Loss: 0.6903, Val Acc: 0.7500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold1
#
# Epoch 2/5
# Training: 100% 27/27 [00:27<00:00,  1.02s/it, loss=0.79, acc=0.562]
# Evaluating: 100% 7/7 [00:07<00:00,  1.13s/it]
# Train Loss: 0.6864, Train Acc: 0.5625
# Val Loss: 0.6644, Val Acc: 0.8500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold1
#
# Epoch 3/5
# Training: 100% 27/27 [00:27<00:00,  1.02s/it, loss=0.621, acc=0.688]
# Evaluating: 100% 7/7 [00:08<00:00,  1.15s/it]
# Train Loss: 0.6195, Train Acc: 0.6875
# Val Loss: 0.5196, Val Acc: 0.9250
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold1
#
# Epoch 4/5
# Training: 100% 27/27 [00:27<00:00,  1.03s/it, loss=0.499, acc=0.906]
# Evaluating: 100% 7/7 [00:08<00:00,  1.15s/it]
# Train Loss: 0.4310, Train Acc: 0.9062
# Val Loss: 0.3931, Val Acc: 1.0000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold1
#
# Epoch 5/5
# Training: 100% 27/27 [00:27<00:00,  1.03s/it, loss=0.604, acc=0.931]
# Evaluating: 100% 7/7 [00:08<00:00,  1.15s/it]
# Train Loss: 0.3228, Train Acc: 0.9313
# Val Loss: 0.3167, Val Acc: 1.0000
#
# ============================================================
# Fold 3/5
# ============================================================
#
# Loading model: roberta-large
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# Starting training for fold 2...
# Train samples: 160, Val samples: 40
#
# Epoch 1/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.708, acc=0.475]
# Evaluating: 100% 7/7 [00:07<00:00,  1.06s/it]
# Train Loss: 0.7057, Train Acc: 0.4750
# Val Loss: 0.6884, Val Acc: 0.6750
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold2
#
# Epoch 2/5
# Training: 100% 27/27 [00:27<00:00,  1.03s/it, loss=0.66, acc=0.544]
# Evaluating: 100% 7/7 [00:07<00:00,  1.12s/it]
# Train Loss: 0.6909, Train Acc: 0.5437
# Val Loss: 0.6720, Val Acc: 0.7000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold2
#
# Epoch 3/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.6, acc=0.675]
# Evaluating: 100% 7/7 [00:07<00:00,  1.14s/it]
# Train Loss: 0.6239, Train Acc: 0.6750
# Val Loss: 0.5900, Val Acc: 0.7500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold2
#
# Epoch 4/5
# Training: 100% 27/27 [00:27<00:00,  1.03s/it, loss=0.276, acc=0.838]
# Evaluating: 100% 7/7 [00:08<00:00,  1.15s/it]
# Train Loss: 0.4611, Train Acc: 0.8375
# Val Loss: 0.4656, Val Acc: 0.9000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold2
#
# Epoch 5/5
# Training: 100% 27/27 [00:27<00:00,  1.04s/it, loss=0.21, acc=0.925]
# Evaluating: 100% 7/7 [00:07<00:00,  1.14s/it]
# Train Loss: 0.2783, Train Acc: 0.9250
# Val Loss: 0.4532, Val Acc: 0.8500
#
# ============================================================
# Fold 4/5
# ============================================================
#
# Loading model: roberta-large
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# Starting training for fold 3...
# Train samples: 160, Val samples: 40
#
# Epoch 1/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.732, acc=0.525]
# Evaluating: 100% 7/7 [00:07<00:00,  1.05s/it]
# Train Loss: 0.6957, Train Acc: 0.5250
# Val Loss: 0.6782, Val Acc: 0.6250
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
#
# Epoch 2/5
# Training: 100% 27/27 [00:27<00:00,  1.02s/it, loss=0.454, acc=0.688]
# Evaluating: 100% 7/7 [00:07<00:00,  1.11s/it]
# Train Loss: 0.6166, Train Acc: 0.6875
# Val Loss: 0.6757, Val Acc: 0.7000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
#
# Epoch 3/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.409, acc=0.787]
# Evaluating: 100% 7/7 [00:07<00:00,  1.11s/it]
# Train Loss: 0.5256, Train Acc: 0.7875
# Val Loss: 0.5204, Val Acc: 0.7500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
#
# Epoch 4/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.276, acc=0.863]
# Evaluating: 100% 7/7 [00:07<00:00,  1.12s/it]
# Train Loss: 0.3733, Train Acc: 0.8625
# Val Loss: 0.4001, Val Acc: 0.7750
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
#
# Epoch 5/5
# Training: 100% 27/27 [00:27<00:00,  1.01s/it, loss=0.15, acc=0.912]
# Evaluating: 100% 7/7 [00:07<00:00,  1.13s/it]
# Train Loss: 0.2623, Train Acc: 0.9125
# Val Loss: 0.3546, Val Acc: 0.8000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
#
# ============================================================
# Fold 5/5
# ============================================================
#
# Loading model: roberta-large
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#
# Starting training for fold 4...
# Train samples: 160, Val samples: 40
#
# Epoch 1/5
# Training: 100% 27/27 [00:27<00:00,  1.02s/it, loss=0.63, acc=0.506]
# Evaluating: 100% 7/7 [00:08<00:00,  1.15s/it]
# Train Loss: 0.6970, Train Acc: 0.5062
# Val Loss: 0.6877, Val Acc: 0.6250
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
#
# Epoch 2/5
# Training: 100% 27/27 [00:27<00:00,  1.02s/it, loss=0.56, acc=0.562]
# Evaluating: 100% 7/7 [00:07<00:00,  1.12s/it]
# Train Loss: 0.6877, Train Acc: 0.5625
# Val Loss: 0.6663, Val Acc: 0.6500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
#
# Epoch 3/5
# Training: 100% 27/27 [00:27<00:00,  1.02s/it, loss=0.39, acc=0.769]
# Evaluating: 100% 7/7 [00:07<00:00,  1.13s/it]
# Train Loss: 0.5140, Train Acc: 0.7688
# Val Loss: 0.5493, Val Acc: 0.6750
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
#
# Epoch 4/5
# Training: 100% 27/27 [00:27<00:00,  1.00s/it, loss=0.147, acc=0.944]
# Evaluating: 100% 7/7 [00:07<00:00,  1.10s/it]
# Train Loss: 0.2451, Train Acc: 0.9437
# Val Loss: 0.4386, Val Acc: 0.7500
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
#
# Epoch 5/5
# Training: 100% 27/27 [00:27<00:00,  1.03s/it, loss=0.0145, acc=0.95]
# Evaluating: 100% 7/7 [00:08<00:00,  1.15s/it]
# Train Loss: 0.1453, Train Acc: 0.9500
# Val Loss: 0.4181, Val Acc: 0.8000
# New best validation accuracy! Saving model to /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
#
# ============================================================
# K-Fold Cross-Validation Results
# ============================================================
# Fold 0: Val Acc = 0.8250
# Fold 1: Val Acc = 1.0000
# Fold 2: Val Acc = 0.9000
# Fold 3: Val Acc = 0.8000
# Fold 4: Val Acc = 0.8000
#
# Mean Accuracy: 0.8650 ± 0.0768
#
# Results saved to: /content/drive/MyDrive/narrative_similarity/models/kfold_results.json
#
# ✓ Training complete!

# %% [markdown]
# Download models

# %% [markdown]
# Track B Inference

# %%
# !python track_b.py
# Out:
# 2025-12-11 22:53:18.365097: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765493598.387234    1101 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765493598.393361    1101 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765493598.408209    1101 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765493598.408243    1101 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765493598.408247    1101 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765493598.408251    1101 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-11 22:53:18.412749: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ============================================================
# TRACK B INFERENCE - GOOGLE COLAB
# ============================================================
# 🔧 Setting up Google Colab environment...
# ✓ Drive already mounted
# ✓ Drive directory: /content/drive/MyDrive/narrative_similarity
# ✓ Data files found in Drive
# ✓ Working directory: /content/project
# ✓ Scripts from repository: /content/project
# ✓ Setup complete!
#   - Scripts: /content/project
#   - Data: /content/drive/MyDrive/narrative_similarity/data
#   - Models: /content/drive/MyDrive/narrative_similarity/models
#
# 🎮 GPU: Tesla T4
# 💾 VRAM: 14.74 GB
#
# Loading configuration...
#
# Loading Track B data from Drive...
# ✓ Loaded 479 texts from: /content/drive/MyDrive/narrative_similarity/data/dev_track_b.jsonl
#
# Loading fine-tuned model from Drive...
#   Model: /content/drive/MyDrive/narrative_similarity/models/track_b_embedder
# ✓ Model loaded
#
# Generating embeddings...
# Batches: 100% 15/15 [00:04<00:00,  3.02it/s]
# ✓ Embeddings generated in 5.0 seconds
#   (95.9 samples/sec)
#   Shape: (479, 768)
#
# Evaluating on Track A dev set...
# ✓ Accuracy: 0.8750
#
# Saving embeddings to Drive...
#
# ============================================================
# ✓ Embeddings saved to: /content/drive/MyDrive/narrative_similarity/output/track_b.npy
# ✓ Accuracy: 0.8750
# ✓ Total time: 55.2 seconds (0.9 minutes)
# ============================================================

# %% [markdown]
# Track A Inference

# %%
# !python track_a.py
# Out:
# ============================================================
# TRACK A INFERENCE - GOOGLE COLAB
# ============================================================
# 🔧 Setting up Google Colab environment...
# ✓ Drive already mounted
# ✓ Drive directory: /content/drive/MyDrive/narrative_similarity
# ✓ Data files found in Drive
# ✓ Working directory: /content/project
# ✓ Scripts from repository: /content/project
# ✓ Setup complete!
#   - Scripts: /content/project
#   - Data: /content/drive/MyDrive/narrative_similarity/data
#   - Models: /content/drive/MyDrive/narrative_similarity/models
#
# 🎮 GPU: Tesla T4
# 💾 VRAM: 14.74 GB
#
# Loading configuration...
#
# Loading data from Drive...
# ✓ Loaded 200 samples from: /content/drive/MyDrive/narrative_similarity/data/dev_track_a.jsonl
#
# Initializing model from Drive...
#
# ============================================================
# ENSEMBLE MODE: 5 models (method: average)
# ============================================================
# Initializing ensemble with 5 models (method: average)
#   Loading fold 0: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
# Loading model from: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold0
# 2025-12-11 22:54:54.943309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765493694.959918    1562 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765493694.965135    1562 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765493694.980096    1562 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765493694.980121    1562 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765493694.980125    1562 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765493694.980129    1562 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-11 22:54:54.984728: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model loaded on device: cuda
#   Loading fold 1: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold1
# Loading model from: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold1
# Model loaded on device: cuda
#   Loading fold 2: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold2
# Loading model from: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold2
# Model loaded on device: cuda
#   Loading fold 3: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
# Loading model from: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold3
# Model loaded on device: cuda
#   Loading fold 4: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
# Loading model from: /content/drive/MyDrive/narrative_similarity/models/track_a_cross_encoder_fold4
# Model loaded on device: cuda
#
# Starting inference...
#
# ============================================================
# Running ensemble inference on 200 samples...
# ============================================================
#
# [1/5] Processing fold 0 model...
#
# [2/5] Processing fold 1 model...
#
# [3/5] Processing fold 2 model...
#
# [4/5] Processing fold 3 model...
#
# [5/5] Processing fold 4 model...
#
# Averaging scores from 5 models...
# Traceback (most recent call last):
#   File "/content/project/track_a.py", line 471, in <module>
#     main()
#   File "/content/project/track_a.py", line 432, in main
#     predictions = predictor.predict_batch(df, batch_size=batch_size)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/project/track_a.py", line 214, in predict_batch
#     return self._predict_average(df, batch_size)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/project/track_a.py", line 240, in _predict_average
#     avg_scores_a = torch.tensor(all_scores_a).mean(dim=0)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: only one element tensors can be converted to Python scalars

# %% [markdown]
# Evaluate results

# %%
# !python scripts/eval_local.py --track both

# %% [markdown]
# CELL 8: Download Results

# %%
# Create output directory in Drive
# !mkdir -p /content/drive/MyDrive/narrative_similarity/output

# Copy inference results to Drive
# !cp -r /content/project/output/* /content/drive/MyDrive/narrative_similarity/output/

# Verify files were saved
# !ls -lh /content/drive/MyDrive/narrative_similarity/output/

print("✓ Results saved to Google Drive:")
print("  - track_a.jsonl (predictions)")
print("  - track_b.npy (embeddings)")
print("  - Access at: MyDrive/narrative_similarity/output/")

# %% [markdown]
# Download models to run locally

# %%
import os

# Define the directory on Google Drive where you want to save the zip file
drive_output_path = "/content/drive/MyDrive/narrative_similarity"

# Ensure the output directory exists
os.makedirs(drive_output_path, exist_ok=True)

# Change to the directory containing the models you want to zip
# %cd /content/drive/MyDrive/narrative_similarity

# Create the zip file directly in the specified Google Drive path
# !zip -r "{drive_output_path}/trained_models.zip" models/
# Out:
# /content/drive/MyDrive/narrative_similarity
#   adding: models/ (stored 0%)
#   adding: models/track_b_embedder_temp/ (stored 0%)
#   adding: models/track_b_embedder_temp/eval/ (stored 0%)
#   adding: models/track_b_embedder/ (stored 0%)
#   adding: models/track_b_embedder/1_Pooling/ (stored 0%)
#   adding: models/track_b_embedder/1_Pooling/config.json (deflated 59%)
#   adding: models/track_b_embedder/2_Normalize/ (stored 0%)
#   adding: models/track_b_embedder/model.safetensors (deflated 12%)
#   adding: models/track_b_embedder/config_sentence_transformers.json (deflated 40%)
#   adding: models/track_b_embedder/config.json (deflated 48%)
#   adding: models/track_b_embedder/sentence_bert_config.json (deflated 9%)
#   adding: models/track_b_embedder/README.md (deflated 68%)
#   adding: models/track_b_embedder/special_tokens_map.json (deflated 80%)
#   adding: models/track_b_embedder/modules.json (deflated 62%)
#   adding: models/track_b_embedder/tokenizer_config.json (deflated 74%)
#   adding: models/track_b_embedder/tokenizer.json (deflated 71%)
#   adding: models/track_b_embedder/vocab.txt (deflated 53%)
#   adding: models/track_b_embedder_temp2/ (stored 0%)
#   adding: models/track_b_embedder_temp2/eval/ (stored 0%)
#   adding: models/track_a_cross_encoder_fold0/ (stored 0%)
#   adding: models/track_a_cross_encoder_fold0/config.json (deflated 49%)
#   adding: models/track_a_cross_encoder_fold0/model.safetensors (deflated 11%)
#   adding: models/track_a_cross_encoder_fold0/merges.txt (deflated 53%)
#   adding: models/track_a_cross_encoder_fold0/tokenizer_config.json (deflated 75%)
#   adding: models/track_a_cross_encoder_fold0/special_tokens_map.json (deflated 52%)
#   adding: models/track_a_cross_encoder_fold0/vocab.json (deflated 59%)
#   adding: models/track_a_cross_encoder_fold0/tokenizer.json (deflated 82%)
#   adding: models/track_a_cross_encoder_fold1/ (stored 0%)
#   adding: models/track_a_cross_encoder_fold1/config.json (deflated 49%)
#   adding: models/track_a_cross_encoder_fold1/model.safetensors (deflated 11%)
#   adding: models/track_a_cross_encoder_fold1/tokenizer_config.json (deflated 75%)
#   adding: models/track_a_cross_encoder_fold1/special_tokens_map.json (deflated 52%)
#   adding: models/track_a_cross_encoder_fold1/merges.txt (deflated 53%)
#   adding: models/track_a_cross_encoder_fold1/vocab.json (deflated 59%)
#   adding: models/track_a_cross_encoder_fold1/tokenizer.json (deflated 82%)
#   adding: models/track_a_cross_encoder_fold2/ (stored 0%)
#   adding: models/track_a_cross_encoder_fold2/config.json (deflated 49%)
#   adding: models/track_a_cross_encoder_fold2/model.safetensors (deflated 11%)
#   adding: models/track_a_cross_encoder_fold2/special_tokens_map.json (deflated 52%)
#   adding: models/track_a_cross_encoder_fold2/merges.txt (deflated 53%)
#   adding: models/track_a_cross_encoder_fold2/vocab.json (deflated 59%)
#   adding: models/track_a_cross_encoder_fold2/tokenizer_config.json (deflated 75%)
#   adding: models/track_a_cross_encoder_fold2/tokenizer.json (deflated 82%)
#   adding: models/track_a_cross_encoder_fold3/ (stored 0%)
#   adding: models/track_a_cross_encoder_fold3/config.json (deflated 49%)
#   adding: models/track_a_cross_encoder_fold3/model.safetensors (deflated 11%)
#   adding: models/track_a_cross_encoder_fold3/tokenizer.json (deflated 82%)
#   adding: models/track_a_cross_encoder_fold3/vocab.json (deflated 59%)
#   adding: models/track_a_cross_encoder_fold3/special_tokens_map.json (deflated 52%)
#   adding: models/track_a_cross_encoder_fold3/merges.txt (deflated 53%)
#   adding: models/track_a_cross_encoder_fold3/tokenizer_config.json (deflated 75%)
#   adding: models/track_a_cross_encoder_fold4/ (stored 0%)
#   adding: models/track_a_cross_encoder_fold4/model.safetensors (deflated 11%)
#   adding: models/track_a_cross_encoder_fold4/config.json (deflated 49%)
#   adding: models/track_a_cross_encoder_fold4/tokenizer_config.json (deflated 75%)
#   adding: models/track_a_cross_encoder_fold4/vocab.json (deflated 59%)
#   adding: models/track_a_cross_encoder_fold4/special_tokens_map.json (deflated 52%)
#   adding: models/track_a_cross_encoder_fold4/merges.txt (deflated 53%)
#   adding: models/track_a_cross_encoder_fold4/tokenizer.json (deflated 82%)
#   adding: models/kfold_results.json (deflated 78%)
